# %%
import numpy as np

# %%
label_test = np.array([True, True, False, True, True])

# %%
label_predicted = np.array([True, False, False, False, False])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(label_test, label_predicted)
# Out:
# array([[1, 0],
#        [3, 1]])
