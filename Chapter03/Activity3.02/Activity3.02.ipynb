# %%
from numpy import loadtxt
from urllib.request import urlopen

# %%
def load_numpy(url):
    raw_data = urlopen(url)
    return loadtxt(raw_data, delimiter=",")

# %%
features_train = np.load(, allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1be3d68092ef> in <module>
# ----> 1 features_train = np.load('https://github.com/PacktWorkshops/The-Applied-Artificial-Intelligence-Workshop/blob/master/Chapter03/features_train.npy?raw=true', allow_pickle=True)
#
# ~/.local/share/virtualenvs/The-Applied-Artificial-Intelligence-Worksh-YQaxNnEL/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/PacktWorkshops/The-Applied-Artificial-Intelligence-Workshop/blob/master/Chapter03/features_train.npy?raw=true'

# %%
features_test = np.load('')

# %%
label_train = np.load('')

# %%
label_test = np.load('')

# %%
file_url = 'https://raw.githubusercontent.com/PacktWorkshops/The-Applied-Artificial-Intelligence-Workshop/master/Chapter03/features_test.out'

# %%
features_train = np.DataSource('.').open(path=file_url)

# %%
features_train
# Out:
# <_io.TextIOWrapper name='/Users/anthonyso/git/packt/The-Applied-Artificial-Intelligence-Workshop/Chapter03/Activity3.02/github.com/PacktWorkshops/The-Applied-Artificial-Intelligence-Workshop/blob/master/Chapter03/features_train.npy' mode='r' encoding='UTF-8'>

# %%
# Load CSV from URL using NumPy
from numpy import loadtxt
from urllib.request import urlopen
raw_data = urlopen(file_url)
dataset = loadtxt(raw_data, delimiter=",")

# %%
type(dataset)
# Out:
# numpy.ndarray

# %%
import pandas as pd

# %%
pd.read_csv(file_url, header=None)
# Out:
#            0         1     2         3         4     5     6         7   \
# 0    1.000000  0.470588  0.25  0.333333  0.300484  0.00  0.00  1.000000
# 1    0.333333  0.294118  1.00  0.777778  0.212391  0.25  0.00  0.666667
# 2    1.000000  0.117647  0.25  0.777778  0.063387  0.75  0.75  0.666667
# 3    0.333333  0.235294  0.25  0.777778  0.221305  0.25  0.00  0.000000
# 4    0.333333  0.205882  1.00  0.111111  0.157038  0.25  0.75  0.666667
# ..        ...       ...   ...       ...       ...   ...   ...       ...
# 195  1.000000  0.205882  0.25  0.444444  0.320238  0.25  0.00  0.666667
# 196  1.000000  0.426471  0.25  0.333333  0.385331  0.25  0.75  0.666667
# 197  0.333333  0.205882  0.25  0.444444  0.089689  0.25  0.75  1.000000
# 198  1.000000  0.647059  0.75  0.111111  0.252779  0.25  1.00  0.666667
# 199  1.000000  0.117647  0.75  0.111111  0.071091  0.25  0.75  0.333333
#
#            8    9         10        11        12   13   14        15  \
# 0    1.000000  1.0  0.333333  0.333333  0.339286  0.5  0.5  0.333333
# 1    1.000000  1.0  1.000000  1.000000  0.071429  0.0  1.0  0.333333
# 2    0.000000  1.0  1.000000  0.333333  0.321429  0.5  1.0  0.000000
# 3    0.000000  1.0  1.000000  0.000000  0.089286  0.5  0.5  0.333333
# 4    1.000000  1.0  0.000000  0.000000  0.214286  0.0  0.5  0.000000
# ..        ...  ...       ...       ...       ...  ...  ...       ...
# 195  1.000000  1.0  1.000000  0.333333  0.250000  0.5  0.5  0.333333
# 196  1.000000  1.0  0.333333  0.333333  0.285714  0.5  0.5  0.333333
# 197  0.666667  1.0  0.000000  0.000000  0.232143  0.5  0.5  0.333333
# 198  1.000000  1.0  0.333333  0.333333  0.250000  0.0  1.0  0.000000
# 199  1.000000  1.0  1.000000  0.333333  0.303571  0.5  0.5  0.000000
#
#            16   17   18   19
# 0    0.000000  0.0  1.0  1.0
# 1    0.333333  1.0  0.0  1.0
# 2    0.333333  0.0  1.0  1.0
# 3    0.333333  0.0  0.0  1.0
# 4    0.333333  0.0  1.0  1.0
# ..        ...  ...  ...  ...
# 195  0.333333  0.0  1.0  1.0
# 196  0.000000  0.0  1.0  1.0
# 197  0.000000  0.0  1.0  1.0
# 198  0.000000  0.0  1.0  1.0
# 199  0.333333  0.0  1.0  1.0
#
# [200 rows x 20 columns]
